# %% [markdown]
# ## Plotting tracked data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv('track_boat1.csv')
data1.dropna(inplace=True)

# %%
data1
# Out:
#             x         y         z
# 12  -0.844135  0.354107  1.680071
# 13  -0.845587  0.359428  1.689084
# 14  -0.836645  0.355872  1.687696
# 15  -0.840121  0.359253  1.703554
# 16  -0.808024  0.345322  1.642863
# ..        ...       ...       ...
# 382 -1.106777  0.308724  2.635452
# 383 -1.070550  0.297438  2.549543
# 384 -1.085341  0.302964  2.567416
# 385 -1.050782  0.298269  2.471699
# 386 -1.048444  0.297967  2.433228
#
# [375 rows x 3 columns]

# %% [markdown]
# ### Track 1

# %%
plt.plot(data1['x'],data1['z'])

# %%
import plotly.graph_objs as go


# Create a 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=data1['x'],
    y=data1['z'],
    mode='lines',
    marker=dict(size=10, color='blue'),
    line=dict(color='blue')
)])

# Set labels and title
fig.update_layout(
    title="Rover trajectory with respect to the camera",
    xaxis_title='X Axis',
    yaxis_title='Z Axis'
)

# Show the interactive plot
fig.show()

# %%
data2 = pd.read_csv('track_boat2_final.csv')
data2
# Out:
#             x         y         z
# 0    0.889747  0.383363  1.933509
# 1    0.859995  0.366332  1.885784
# 2    0.855739  0.365714  1.878214
# 3    0.881580  0.366325  1.960399
# 4    0.870081  0.363002  1.942498
# ..        ...       ...       ...
# 268 -1.082472  0.404450  2.299731
# 269 -1.108071  0.411028  2.349059
# 270 -1.088591  0.403957  2.289426
# 271 -1.048038  0.391874  2.191338
# 272 -1.039943  0.391161  2.164181
#
# [273 rows x 3 columns]

# %%
data2.dropna(inplace=True)

# %% [markdown]
# ### Track 2

# %%
plt.plot(data2['x'],data2['z'])

# %%
# Create a 2D scatter plot
fig = go.Figure(data=[go.Scatter(
    x=data2['x'],
    y=data2['z'],
    mode='lines',
    marker=dict(size=10, color='blue'),
    line=dict(color='blue')
)])

# Set labels and title
fig.update_layout(
    title="Rover trajectory with respect to the camera (track 2)",
    xaxis_title='X Axis',
    yaxis_title='Z Axis'
)

# Show the interactive plot
fig.show()
